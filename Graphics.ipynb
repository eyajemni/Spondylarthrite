# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_excel('Pilot_006_JeEy_Ext.xlsx', sheet_name ="Segment Orientation - Euler")
data
# Out:
#       Frame  Pelvis x  Pelvis y  Pelvis z      L5 x      L5 y      L5 z  \
# 0         0  0.448622  5.990280 -1.273833  0.602206  3.469309 -1.244492
# 1         1  0.424793  5.903247 -1.249568  0.576750  3.393026 -1.228636
# 2         2  0.400930  5.816224 -1.225270  0.551274  3.316751 -1.212748
# 3         3  0.379730  5.736883 -1.203414  0.528189  3.246465 -1.198424
# 4         4  0.362111  5.669308 -1.185078  0.508431  3.185139 -1.186371
# ...     ...       ...       ...       ...       ...       ...       ...
# 2051   2051  0.811164  7.224957  4.582817 -1.146716  5.171185  4.602143
# 2052   2052  0.813088  7.197634  4.683008 -1.128322  5.243933  4.661596
# 2053   2053  0.818017  7.189442  4.782859 -1.105058  5.315306  4.722856
# 2054   2054  0.825131  7.191941  4.882298 -1.078426  5.386698  4.785308
# 2055   2055  0.832249  7.194427  4.981738 -1.051712  5.458060  4.847800
#
#           L3 x      L3 y      L3 z  ...  Left Upper Leg z  Left Lower Leg x  \
# ...

# %%
data.loc[:,["Frame","Pelvis x","Pelvis y","Pelvis z"]]
# Out:
#       Frame  Pelvis x  Pelvis y  Pelvis z
# 0         0  0.448622  5.990280 -1.273833
# 1         1  0.424793  5.903247 -1.249568
# 2         2  0.400930  5.816224 -1.225270
# 3         3  0.379730  5.736883 -1.203414
# 4         4  0.362111  5.669308 -1.185078
# ...     ...       ...       ...       ...
# 2051   2051  0.811164  7.224957  4.582817
# 2052   2052  0.813088  7.197634  4.683008
# 2053   2053  0.818017  7.189442  4.782859
# 2054   2054  0.825131  7.191941  4.882298
# 2055   2055  0.832249  7.194427  4.981738
#
# [2056 rows x 4 columns]

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')

# %%
X=data.loc[:,'Pelvis x']
X
# Out:
# 0       0.448622
# 1       0.424793
# 2       0.400930
# 3       0.379730
# 4       0.362111
#           ...
# 2051    0.811164
# 2052    0.813088
# 2053    0.818017
# 2054    0.825131
# 2055    0.832249
# Name: Pelvis x, Length: 2056, dtype: float64

# %%
Y=data.loc[:,'Pelvis y']
Y
# Out:
# 0       5.990280
# 1       5.903247
# 2       5.816224
# 3       5.736883
# 4       5.669308
#           ...
# 2051    7.224957
# 2052    7.197634
# 2053    7.189442
# 2054    7.191941
# 2055    7.194427
# Name: Pelvis y, Length: 2056, dtype: float64

# %%
Z=data.loc[:,'Pelvis z']
Z
# Out:
# 0      -1.273833
# 1      -1.249568
# 2      -1.225270
# 3      -1.203414
# 4      -1.185078
#           ...
# 2051    4.582817
# 2052    4.683008
# 2053    4.782859
# 2054    4.882298
# 2055    4.981738
# Name: Pelvis z, Length: 2056, dtype: float64

# %%
F=data.loc[:,'Frame']
F
# Out:
# 0          0
# 1          1
# 2          2
# 3          3
# 4          4
#         ...
# 2051    2051
# 2052    2052
# 2053    2053
# 2054    2054
# 2055    2055
# Name: Frame, Length: 2056, dtype: int64

# %%
ax.plot3D(X, Y, Z, 'gray')

# %%
fig

# %%
plt.plot(F,X)
plt.plot(F,Y, 'green')
plt.plot(F,Z, 'red')

# %%
X=np.array(X)
X
# Out:
# array([0.44862203, 0.4247925 , 0.40092964, ..., 0.81801698, 0.82513068,
#        0.83224877])

# %%
Y=np.array(Y)
Y
# Out:
# array([5.99027968, 5.90324673, 5.81622382, ..., 7.18944246, 7.19194082,
#        7.19442693])

# %%
Z=np.array(Z)
Z
# Out:
# array([-1.27383323, -1.24956799, -1.22527015, ...,  4.78285886,
#         4.88229806,  4.98173812])

# %%
fig1 = plt.figure(figsize=(50,50))
ax1 = plt.axes(projection='3d')

# %%
#The scatter() function plots one dot for each observation. It needs three arrays of the same length, one for the values of the x-axis, one for values on the y-axis, and one for values on the z-axis:
ax1.scatter(X,Y,Z, label='Courbe',s=100, marker='d')

# %%
fig1

# %%
fig2 = plt.figure(figsize=(20,20))
ax2 = plt.axes(projection='3d')

# %%
ax2.plot3D(X, Y, Z)

# %%
fig2

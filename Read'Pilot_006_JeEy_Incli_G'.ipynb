# %%
import pandas as pd

# %%
data0=pd.read_excel("Pilot_006_JeEy_Incli_G.xlsx")
data0
# Out:
#           MVN version                                           2020.2.0
# 0  Original File Name  C:\Users\gille\Desktop\Xsens\SPONDYMOVE_Chloe\...
# 1          Suit Label                                         test_pilot
# 2   Recorded Date UTC                                2022-05-03 08:50:08
# 3          Frame Rate                                                 60
# 4  Processing Quality                                               Live

# %%
dataNone=pd.read_excel('Pilot_006_JeEy_Incli_G.xlsx', sheet_name = None)

# %%
dataNone.keys()
# Out:
# dict_keys(['General Information', 'Markers', 'Segment Orientation - Quat', 'Segment Orientation - Euler', 'Segment Position', 'Segment Velocity', 'Segment Acceleration', 'Segment Angular Velocity', 'Segment Angular Acceleration', 'Joint Angles ZXY', 'Joint Angles XZY', 'Ergonomic Joint Angles ZXY', 'Ergonomic Joint Angles XZY', 'Center of Mass', 'Sensor Free Acceleration', 'Sensor Magnetic Field', 'Sensor Orientation - Quat', 'Sensor Orientation - Euler'])

# %%
dataNone
# Out:
# {'General Information':           MVN version                                           2020.2.0
#  0  Original File Name  C:\Users\gille\Desktop\Xsens\SPONDYMOVE_Chloe\...
#  1          Suit Label                                         test_pilot
#  2   Recorded Date UTC                                2022-05-03 08:50:08
#  3          Frame Rate                                                 60
#  4  Processing Quality                                               Live,
#  'Markers': Empty DataFrame
#  Columns: [Frame, Marker Text]
#  Index: [],
#  'Segment Orientation - Quat':       Frame  Pelvis q0  Pelvis q1  Pelvis q2  Pelvis q3     L5 q0     L5 q1  \
#  0         0   0.682410  -0.059941  -0.052317  -0.726627  0.703364 -0.007423
#  1         1   0.683025  -0.058702  -0.051529  -0.726206  0.703778 -0.006651
#  2         2   0.683638  -0.057463  -0.050740  -0.725784  0.704191 -0.005880
#  3         3   0.684215  -0.056342  -0.049980  -0.725381  0.704579 -0.005130
# ...
